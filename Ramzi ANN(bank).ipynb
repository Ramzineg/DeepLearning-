# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense
df=pd.read_csv(r'C:\Users\azur\Downloads\bank (1).csv')
df.head()
# Out:
#    age         job  marital  education default  balance housing loan  contact  \
# 0   59      admin.  married  secondary      no     2343     yes   no  unknown
# 1   56      admin.  married  secondary      no       45      no   no  unknown
# 2   41  technician  married  secondary      no     1270     yes   no  unknown
# 3   55    services  married  secondary      no     2476     yes   no  unknown
# 4   54      admin.  married   tertiary      no      184      no   no  unknown
#
#    day month  duration  campaign  pdays  previous poutcome deposit
# 0    5   may      1042         1     -1         0  unknown     yes
# 1    5   may      1467         1     -1         0  unknown     yes
# 2    5   may      1389         1     -1         0  unknown     yes
# 3    5   may       579         1     -1         0  unknown     yes
# 4    5   may       673         2     -1         0  unknown     yes

# %%
df['month'].value_counts()
# Out:
# may    2824
# aug    1519
# jul    1514
# jun    1222
# nov     943
# apr     923
# feb     776
# oct     392
# jan     344
# sep     319
# mar     276
# dec     110
# Name: month, dtype: int64

# %%
df.isnull().sum()
df.isna().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# deposit      0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
def feature_encoder(*labels):
  for label in labels:
    df[label] = encoder.fit_transform(df[label])
    print(f"{label} is encoded.")

feature_encoder('job',	'marital',	'education',	'default','housing',	'loan'	,'contact','poutcome'	,'deposit','month')
# Out:
# job is encoded.
# marital is encoded.
# education is encoded.
# default is encoded.
# housing is encoded.
# loan is encoded.
# contact is encoded.
# poutcome is encoded.
# deposit is encoded.
# month is encoded.

# %%
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# 1    5      8      1467         1     -1         0         3        1
# 2    5      8      1389         1     -1         0         3        1
# 3    5      8       579         1     -1         0         3        1
# 4    5      8       673         2     -1         0         3        1

# %%
df['balance']=df['balance']/df['balance'].max()
df['balance'].max()
# Out:
# 1.0

# %%
df['duration'].max()
df['duration']=df['duration']/df['duration'].max()
df['duration'].max()
# Out:
# 1.0

# %%
df.head()
# Out:
#    age  job  marital  education  default   balance  housing  loan  contact  \
# 0   59    0        1          1        0  0.028853        1     0        2
# 1   56    0        1          1        0  0.000554        0     0        2
# 2   41    9        1          1        0  0.015640        1     0        2
# 3   55    7        1          1        0  0.030491        1     0        2
# 4   54    0        1          2        0  0.002266        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8  0.268488         1     -1         0         3        1
# 1    5      8  0.377995         1     -1         0         3        1
# 2    5      8  0.357897         1     -1         0         3        1
# 3    5      8  0.149188         1     -1         0         3        1
# 4    5      8  0.173409         2     -1         0         3        1

# %%
X=df.drop('deposit',axis=1)
Y=df['deposit']

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
x_train, x_valid, y_train, y_valid = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
from keras.optimizers import RMSprop
my_model1 = Sequential()
my_model1.add(Dense(input_dim = 16 , units = 1, activation="relu"))
my_model1.add(Dense(input_dim = 16 , units = 1, activation="relu"))
my_model1.add(Dense(input_dim = 16 , units = 1, activation="softmax"))
my_model1.add(Dense(input_dim = 16 , units = 1, activation="softmax"))
my_model1.add(Dense(input_dim = 16 , units = 1, activation="softmax"))
n_epochs = 100
batch_size = 700
learn_rate = 0.01
my_model1.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(),
              metrics=['accuracy'])
history = my_model1.fit(X, Y, validation_split=0.2, epochs=n_epochs, batch_size=batch_size)
# Out:
# Epoch 1/100
# 13/13 [==============================] - 1s 22ms/step - loss: 0.0000e+00 - accuracy: 0.5923 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5923 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5923 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5923 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5923 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0000e+00 - accuracy: 0.5923 - val_loss: 0.0000e+00 - val_accuracy: 0.0000e+00
# Epoch 7/100
# ...
